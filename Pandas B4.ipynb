# %%
import pandas as pd

# %%
x = [1654654654654654654,"hi"]

pd.Series(x)
# Out:
# 0    1654654654654654654
# 1                     hi
# dtype: object

# %%
import numpy as np

a = np.random.randint(1,3,(100,3))

# %%
a.dtype
# Out:
# dtype('int32')

# %%
data = pd.DataFrame(a,columns=["first","second","third"])

# %%
data.head()
# Out:
#    first  second  third
# 0      1       1      1
# 1      2       1      2
# 2      1       2      1
# 3      2       2      2
# 4      1       1      1

# %%
data.tail()
# Out:
#     first  second  third
# 95      1       1      1
# 96      2       2      2
# 97      2       2      1
# 98      2       2      2
# 99      1       2      2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   100 non-null    int32
#  1   second  100 non-null    int32
#  2   third   100 non-null    int32
# dtypes: int32(3)
# memory usage: 1.3 KB

# %%
data.describe()
# Out:
#             first  second       third
# count  100.000000  100.00  100.000000
# mean     1.470000    1.55    1.350000
# std      0.501614    0.50    0.479372
# min      1.000000    1.00    1.000000
# 25%      1.000000    1.00    1.000000
# 50%      1.000000    2.00    1.000000
# 75%      2.000000    2.00    2.000000
# max      2.000000    2.00    2.000000

# %%
data.columns.tolist()
# Out:
# ['first', 'second', 'third']

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
data = pd.read_csv('Housing.csv',encoding='utf-8',delimiter=',')
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# # indexing

# %%
data.iloc[:,0:5]
# Out:
#         price  area  bedrooms  bathrooms  stories
# 0    13300000  7420         4          2        3
# 1    12250000  8960         4          4        4
# 2    12250000  9960         3          2        2
# 3    12215000  7500         4          2        2
# 4    11410000  7420         4          1        2
# ..        ...   ...       ...        ...      ...
# 540   1820000  3000         2          1        1
# 541   1767150  2400         3          1        1
# 542   1750000  3620         2          1        1
# 543   1750000  2910         3          1        1
# 544   1750000  3850         3          1        2
#
# [545 rows x 5 columns]

# %%
data.loc[0:10,'area':'guestroom']
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom
# 0    7420         4          2        3      yes        no
# 1    8960         4          4        4      yes        no
# 2    9960         3          2        2      yes        no
# 3    7500         4          2        2      yes        no
# 4    7420         4          1        2      yes       yes
# 5    7500         3          3        1      yes        no
# 6    8580         4          3        4      yes        no
# 7   16200         5          3        2      yes        no
# 8    8100         4          1        2      yes       yes
# 9    5750         3          2        4      yes       yes
# 10  13200         3          1        2      yes        no

# %%
data.iloc[0::10]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000   7420         4          2        3      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 20    8750000   4320         3          1        2      yes        no
# 30    8400000   7475         3          2        4      yes        no
# 40    7875000   6550         3          1        2      yes        no
# 50    7420000   7440         3          2        4      yes        no
# 60    7140000   6000         3          2        2      yes       yes
# 70    6790000   4000         3          2        2      yes        no
# 80    6629000   6000         3          1        2      yes        no
# 90    6440000   5000         3          1        2      yes        no
# 100   6230000   6600         3          2        1      yes        no
# 110   6090000   6600         3          1        1      yes       yes
# ...

# %%
data.sort_values(by='area',ascending=True)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 449   3150000   1650         3          1        2       no        no
# 537   1890000   1700         3          1        2      yes        no
# 527   2275000   1836         2          1        1       no        no
# 271   4340000   1905         5          1        2       no        no
# 413   3430000   1950         3          2        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 403   3500000  12944         3          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 7    10150000  16200         5          3        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data.iloc[[2,34,56,78]]
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2   12250000   9960         3          2        2      yes        no      yes
# 34   8120000   6840         5          1        2      yes       yes      yes
# 56   7343000  11440         4          1        2      yes        no      yes
# 78   6650000   5700         3          1        1      yes       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 2               no              no        2      yes   semi-furnished
# 34              no             yes        1       no        furnished
# 56              no              no        1      yes   semi-furnished
# 78              no             yes        2      yes        furnished

# %%
data[['area','mainroad','parking']]
# Out:
#      area mainroad  parking
# 0    7420      yes        2
# 1    8960      yes        3
# 2    9960      yes        2
# 3    7500      yes        3
# 4    7420      yes        2
# ..    ...      ...      ...
# 540  3000      yes        2
# 541  2400       no        0
# 542  3620      yes        0
# 543  2910       no        0
# 544  3850      yes        0
#
# [545 rows x 3 columns]

# %%
data.sort_index(ascending=False)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544   1750000  3850         3          1        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 541   1767150  2400         3          1        1       no        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 4    11410000  7420         4          1        2      yes       yes      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 2    12250000  9960         3          2        2      yes        no      yes
# 1    12250000  8960         4          4        4      yes        no       no
# 0    13300000  7420         4          2        3      yes        no       no
#
# ...

# %% [markdown]
# # Conditional selection

# %%
data[data['bedrooms'] == 3]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 2    12250000   9960         3          2        2      yes        no
# 5    10850000   7500         3          3        1      yes        no
# 9     9800000   5750         3          2        4      yes       yes
# 10    9800000  13200         3          1        2      yes        no
# 14    9240000   7800         3          2        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 533   2100000   2400         3          1        2      yes        no
# 537   1890000   1700         3          1        2      yes        no
# 541   1767150   2400         3          1        1       no        no
# 543   1750000   2910         3          1        1       no        no
# 544   1750000   3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
data[data['area'] > 5000]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 487   2870000  5400         4          1        2      yes        no       no
# 488   2852500  5200         4          1        3      yes        no       no
# 494   2730000  6800         2          1        1      yes        no       no
# 520   2450000  7700         2          1        1      yes        no       no
# 531   2233000  5300         3          1        1       no        no       no
#
# ...

# %%
data.loc[(data['area'] > 5000) | (data['mainroad'] == 'yes')]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 537   1890000  1700         3          1        2      yes        no       no
# 538   1890000  3649         2          1        1      yes        no       no
# 540   1820000  3000         2          1        1      yes        no      yes
# 542   1750000  3620         2          1        1      yes        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.isnull()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
data = pd.read_csv('loan.csv')
# Out:
# C:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
data.notnull().sum()
# Out:
# id                            39717
# member_id                     39717
# loan_amnt                     39717
# funded_amnt                   39717
# funded_amnt_inv               39717
#                               ...
# tax_liens                     39678
# tot_hi_cred_lim                   0
# total_bal_ex_mort                 0
# total_bc_limit                    0
# total_il_high_credit_limit        0
# Length: 111, dtype: int64

# %%
data.isnull().any()
# Out:
# id                            False
# member_id                     False
# loan_amnt                     False
# funded_amnt                   False
# funded_amnt_inv               False
#                               ...
# tax_liens                      True
# tot_hi_cred_lim                True
# total_bal_ex_mort              True
# total_bc_limit                 True
# total_il_high_credit_limit     True
# Length: 111, dtype: bool

# %%
data.isna().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,10))
round((data.isnull().sum() / data.shape[0]) * 100).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.drop('id',axis=1)
# Out:
#        member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0        1296599       5000         5000           4975.0   36 months
# 1        1314167       2500         2500           2500.0   60 months
# 2        1313524       2400         2400           2400.0   36 months
# 3        1277178      10000        10000          10000.0   36 months
# 4        1311748       3000         3000           3000.0   60 months
# ...          ...        ...          ...              ...         ...
# 39712      92174       2500         2500           1075.0   36 months
# 39713      90607       8500         8500            875.0   36 months
# 39714      90390       5000         5000           1325.0   36 months
# 39715      89243       5000         5000            650.0   36 months
# 39716      86999       7500         7500            800.0   36 months
#
#       int_rate  installment grade sub_grade                   emp_title  ...  \
# ...

# %%
data.drop(['id','member_id'],axis=1)
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           5000         5000           4975.0   36 months   10.65%
# 1           2500         2500           2500.0   60 months   15.27%
# 2           2400         2400           2400.0   36 months   15.96%
# 3          10000        10000          10000.0   36 months   13.49%
# 4           3000         3000           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 39712       2500         2500           1075.0   36 months    8.07%
# 39713       8500         8500            875.0   36 months   10.28%
# 39714       5000         5000           1325.0   36 months    8.07%
# 39715       5000         5000            650.0   36 months    7.43%
# 39716       7500         7500            800.0   36 months   13.75%
#
#        installment grade sub_grade                   emp_title emp_length  \
# 0           162.87     B        B2                         NaN  10+ years
# ...

# %%
data.loc[3,'id'] = "random"

# %%
pd.concat([data,data,data,data],axis=1)
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3       random    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...
