# %%
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))


import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(1,100,10000)

# %%
plt.plot(gaussian(x,np.mean(x),np.std(x)))
