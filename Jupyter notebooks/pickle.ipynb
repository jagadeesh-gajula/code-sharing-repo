# %%
class config:
    config_code = "this is a code"
    
    def hello(self):
        print("hi user")
    
screen = pyautogui.screenshot()
    
obj = config()


file = open('cofig','wb')

import pickle


pickle.dump(screen,file)

file.close()

# %%
file = open('cofig','rb')
loaded = pickle.load(file)
loaded
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x1E52F312D30>

# %%
loaded.hello()
# Out:
# hi user
