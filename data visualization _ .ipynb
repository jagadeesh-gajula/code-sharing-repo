# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('Housing.csv')

# %%
data.mainroad.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
plt.title("random title")
plt.xlabel("categories")
plt.ylabel('numbers')
plt.bar(['yes','no'],[4,8],color='red')
plt.show()
