# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('usedcars.csv')

# %%
data
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
var = data.model.value_counts()

plt.bar(var.index,var.values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.plot(range(data.shape[0]),data.mileage,color='green')

plt.plot(range(data.shape[0]),data.year)
plt.show()

# %%
sns.histplot(data.mileage)
plt.show()

# %%
plt.pie(x=[1,2,3,4],labels=["one","two","three",'four'],explode=[0.2,0.2,0.2,0.2])
plt.show()

# %%
label = ["one","two","three"]
male = [1,2,3]
female = [4,5,6]
sns.barplot(label,female,color='red')
sns.barplot(label,male)
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(data.mileage,data.year)

# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing().data

# %%
sns.heatmap(pd.DataFrame(data).corr())
# Out:
# <AxesSubplot:>

# %%
sns.regplot(data.year,data.mileage)
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='mileage'>
