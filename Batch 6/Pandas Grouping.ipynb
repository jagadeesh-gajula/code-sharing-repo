# %%
import pandas as pd

# %%
data = pd.read_csv('housing.csv')

# %%
data.groupby('mainroad').mean()
# Out:
#                  price         area  bedrooms  bathrooms   stories   parking
# mainroad
# no        3.398905e+06  3606.441558  2.987013   1.233766  1.545455  0.259740
# yes       4.991777e+06  5404.591880  2.961538   1.294872  1.848291  0.764957

# %%
data.pivot_table(index='bedrooms',values='price',aggfunc='count')
# Out:
#           price
# bedrooms
# 1             2
# 2           136
# 3           300
# 4            95
# 5            10
# 6             2

# %%
data['random'] = 10

# %%
data['added_bath_bed_rooms'] = data['bathrooms'] + data['bedrooms']

# %%
def fun(x):
    return x + 200

data['bathrooms'] = fun(data.bathrooms)

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4        202        3      yes        no       no
# 1    12250000  8960         4        204        4      yes        no       no
# 2    12250000  9960         3        202        2      yes        no      yes
# 3    12215000  7500         4        202        2      yes        no      yes
# 4    11410000  7420         4        201        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2        201        1      yes        no      yes
# 541   1767150  2400         3        201        1       no        no       no
# 542   1750000  3620         2        201        1      yes        no       no
# 543   1750000  2910         3        201        1       no        no       no
# 544   1750000  3850         3        201        2      yes        no       no
#
# ...

# %%
data = data.drop(['area','price','bathrooms'],axis=1)

# %%
data = data.drop([0,1,2,3],axis=0)

# %%
df = data.drop([4,5,6],axis=0)

# %%
hi = df.copy()

# %%
hi
# Out:
#      bedrooms  stories mainroad guestroom basement hotwaterheating  \
# 7           5        2      yes        no       no              no
# 8           4        2      yes       yes      yes              no
# 9           3        4      yes       yes       no              no
# 10          3        2      yes        no      yes              no
# 11          4        2      yes       yes      yes             yes
# ..        ...      ...      ...       ...      ...             ...
# 540         2        1      yes        no      yes              no
# 541         3        1       no        no       no              no
# 542         2        1      yes        no       no              no
# 543         3        1       no        no       no              no
# 544         3        2      yes        no       no              no
#
#     airconditioning  parking prefarea furnishingstatus  random  \
# 7                no        0       no      unfurnished      10
# ...

# %%
def function(x):
    try:
        y = x ** 2
        z =  y + 100 ** 2
        return z
    except:
        return str(x)


data.bedrooms.astype(int).apply(lambda a:function(a)).value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='bedrooms'>
