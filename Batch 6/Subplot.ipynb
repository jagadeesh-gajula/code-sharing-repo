# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plot1 = plt.subplot(3,2,1)
plot2 = plt.subplot(3,2,2)
plot3 = plt.subplot(3,2,3)
plot4 = plt.subplot(3,2,4)

plot1.bar([1,2,3],[1,2,3])
plot2.plot([1,2,3],[4,5,6])
plot3.pie([1,2,3])
plot4.scatter([1,2,3],[34,2,6])

plt.show()

# %%
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing().data
import pandas as pd

# %%
data.shape
# Out:
# (20640, 8)

# %%
sns.pairplot(pd.DataFrame(data))
