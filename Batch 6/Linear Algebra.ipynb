# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
o = np.array([0,0])
v = np.array([2,3])

i = np.array([[1,2],[1,2]])

v2 = v
v = np.dot(i,v)

plt.plot((o[0],v[0]),(o[1],v[1]),color='green')
plt.plot((o[0],v2[0]),(o[1],v2[1]),color='red')
