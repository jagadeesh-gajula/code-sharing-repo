# %%
import pandas as pd
import seaborn as sns

data = pd.read_csv('Housing.csv')

# %%
data.shape
# Out:
# (545, 13)

# %%
sns.regplot(x='price',y='area',data=data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='area'>

# %%
pd.DataFrame(data.bedrooms.value_counts())
# Out:
#    bedrooms
# 3       300
# 2       136
# 4        95
# 5        10
# 6         2
# 1         2

# %%
import matplotlib.pyplot as plt

plt.bar([3,2,5,4,6,1],[300,436,531,541,543,545])
# Out:
# <BarContainer object of 6 artists>
