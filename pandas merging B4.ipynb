# %%
import pandas as pd

# %%
company = pd.read_csv('company.csv',delimiter='\t')
rounds = pd.read_csv('rounds2.csv',encoding='iso-8859-1')

# %%
company.permalink = company.permalink.astype('str').apply(lambda x:x.lower())

# %%
company
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                               /organization/ãeron
# 66366                             /organization/ã”asys-2
# 66367  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
rounds
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /organization/ãeron
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
pd.merge(left=company,right=rounds,how='inner',on='permalink')
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                                  /organization/0-6-com
# 3                       /organization/01games-technology
# 4                    /organization/0ndine-biomedical-inc
# ...                                                  ...
# 57458                                /organization/zzish
# 57459                          /organization/zzzzapp-com
# 57460                          /organization/zzzzapp-com
# 57461                               /organization/ãeron
# 57462  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                 name            homepage_url  \
# 0                                              #fame      http://livfame.com
# 1                                           :Qounter  http://www.qounter.com
# ...

# %%
pd.merge(left=company,right=rounds,how='left',on='permalink')
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 78692                          /organization/zzzzapp-com
# 78693                          /organization/zzzzapp-com
# 78694                               /organization/ãeron
# 78695                             /organization/ã”asys-2
# 78696  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
pd.merge(left=company,right=rounds,how='right',on='permalink')
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /organization/ãeron
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                  name            homepage_url  \
# 0                                               #fame      http://livfame.com
# 1                                                 NaN                     NaN
# ...

# %%
pd.merge(left=company,right=rounds,how='outer',on='permalink')
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                     /organization/-the-one-of-them-inc-
# 3                                   /organization/0-6-com
# 4                          /organization/004-technologies
# ...                                                   ...
# 136178                                /ORGANIZATION/ZZISH
# 136179  /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO...
# 136180                          /ORGANIZATION/ZZZZAPP-COM
# 136181                          /ORGANIZATION/ZZZZAPP-COM
# 136182                             /ORGANIZATION/ÃASYS-2
#
#                           name                       homepage_url  \
# 0                        #fame                 http://livfame.com
# 1                     :Qounter             http://www.qounter.com
# 2       (THE) ONE of THEM,Inc.                http://oneofthem.jp
# ...

# %% [markdown]
# # Grouping

# %%
data.groupby('funding_round_type').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2171d7e9d6f5> in <module>
# ----> 1 data.groupby('funding_round_type').mean()
#
# NameError: name 'data' is not defined

# %% [markdown]
# # applying custom functions

# %%
def fun(x):
    x = str(x)
    return x.split('.')[-1]

# %%
company['country_code_lowercase'] = company['country_code'].astype('str').apply(lambda x:x.lower())

# %%
company['random_col'] = 789

# %%
company
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                               /organization/ãeron
# 66366                             /organization/ã”asys-2
# 66367  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                 name        homepage_url  \
# 0                                              #fame                 com
# 1                                           :Qounter                 com
# ...

# %%
company['country_code'].fillna("your name")
# Out:
# 0              IND
# 1              USA
# 2        your name
# 3              CHN
# 4              USA
#            ...
# 66363          CHN
# 66364          HRV
# 66365    your name
# 66366          USA
# 66367    your name
# Name: country_code, Length: 66368, dtype: object

# %%
company.fillna(0)
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# ...                                                  ...
# 66363  /organization/zznode-science-and-technology-co...
# 66364                          /organization/zzzzapp-com
# 66365                               /organization/ãeron
# 66366                             /organization/ã”asys-2
# 66367  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                                 name        homepage_url  \
# 0                                              #fame                 com
# 1                                           :Qounter                 com
# ...

# %% [markdown]
# # summarizing

# %%
data = pd.read_csv('Housing.csv')

# %%
data.pivot_table(values='area',index='parking',aggfunc='mean')
# Out:
#                 area
# parking
# 0        4501.120401
# 1        5576.357143
# 2        6226.379630
# 3        7178.333333

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...
