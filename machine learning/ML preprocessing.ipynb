# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Data.csv')

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data['Country'].values
# Out:
# array(['France', 'Spain', 'Germany', 'Spain', 'Germany', 'France',
#        'Spain', 'France', 'Germany', 'France'], dtype=object)

# %%
#from sklearn.preprocessing import LabelEncoder

#encoder = LabelEncoder()
#encoder.fit(data['Country'].values)
#data['Country'] = encoder.transform(data['Country'].values)

# %%
pd.get_dummies(data)
# Out:
#     Age   Salary  Country_France  Country_Germany  Country_Spain  \
# 0  44.0  72000.0               1                0              0
# 1  27.0  48000.0               0                0              1
# 2  30.0  54000.0               0                1              0
# 3  38.0  61000.0               0                0              1
# 4  40.0      NaN               0                1              0
# 5  35.0  58000.0               1                0              0
# 6   NaN  52000.0               0                0              1
# 7  48.0  79000.0               1                0              0
# 8  50.0  83000.0               0                1              0
# 9  37.0  67000.0               1                0              0
#
#    Purchased_No  Purchased_Yes
# 0             1              0
# 1             0              1
# 2             1              0
# 3             1              0
# 4             0              1
# 5             0              1
# 6             1              0
# 7             0              1
# 8             1              0
# 9             0              1

# %%
from sklearn.impute import SimpleImputer


imputer  = SimpleImputer(strategy="mean")
data['Age'] = imputer.fit_transform(data[['Age']])

# %%
from sklearn.impute import SimpleImputer


imputer  = SimpleImputer(strategy="mean")
data['Salary'] = imputer.fit_transform(data[['Salary']])

# %%
plt.hist(data['Age'])
# Out:
# (array([1., 1., 0., 1., 2., 2., 0., 1., 0., 2.]),
#  array([27. , 29.3, 31.6, 33.9, 36.2, 38.5, 40.8, 43.1, 45.4, 47.7, 50. ]),
#  <a list of 10 Patch objects>)

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
data['Age'] = scaler.fit_transform(data[['Age']])

# %%
data = pd.get_dummies(data)

# %%
data
# Out:
#         Age        Salary  Country_France  Country_Germany  Country_Spain  \
# 0  0.758874  72000.000000               1                0              0
# 1 -1.711504  48000.000000               0                0              1
# 2 -1.275555  54000.000000               0                1              0
# 3 -0.113024  61000.000000               0                0              1
# 4  0.177609  63777.777778               0                1              0
# 5 -0.548973  58000.000000               1                0              0
# 6  0.000000  52000.000000               0                0              1
# 7  1.340140  79000.000000               1                0              0
# 8  1.630773  83000.000000               0                1              0
# 9 -0.258340  67000.000000               1                0              0
#
#    Purchased_No  Purchased_Yes
# 0             1              0
# 1             0              1
# 2             1              0
# 3             1              0
# 4             0              1
# 5             0              1
# 6             1              0
# 7             0              1
# 8             1              0
# 9             0              1

# %%
theta = np.zeros((x.shape[1],1))

m = data.shape[0]
x = data.drop('Salary',axis=1).values
y = data['Salary'].values
alpha = 0.000001
for i in range(10):
    gradient = 1/m *( np.matmul(x.T,np.matmul(x,theta))- y )
    theta = theta - alpha * gradient
    print(theta)
# Out:
# [[0.0072     0.0048     0.0054     0.0061     0.00637778 0.0058
#  [0.05759981 0.03839988 0.04319986 0.04879984 0.05102206 0.04639985
#   0.04159986 0.06319979 0.06639978 0.05359983]
#  [0.05759987 0.03839991 0.0431999  0.04879989 0.05102211 0.04639989
#   0.0415999  0.06319986 0.06639985 0.05359988]
#  [0.05759992 0.03839994 0.04319994 0.04879993 0.05102215 0.04639993
#   0.04159994 0.06319991 0.0663999  0.05359992]
#  [0.05759978 0.03839985 0.04319983 0.04879981 0.05102203 0.04639982
#   0.04159984 0.06319976 0.06639974 0.05359979]
#  [0.05759982 0.03839988 0.04319986 0.04879985 0.05102206 0.04639985
#   0.04159987 0.0631998  0.06639979 0.05359983]]
# [[0.06479974 0.04319983 0.04859981 0.05489978 0.05739977 0.05219979
#   0.04679981 0.07109972 0.0746997  0.06029976]
#  [0.06479976 0.04319984 0.04859982 0.0548998  0.05739979 0.05219981
#   0.04679983 0.07109974 0.07469972 0.06029978]
#  [0.06479983 0.04319989 0.04859987 0.05489986 0.05739985 0.05219986
#   0.04679988 0.07109981 0.0746998  0.06029984]
#  [0.06479989 0.04319993 0.04859992 0.05489991 0.0573999  0.05219991
#   0.04679992 0.07109988 0.07469988 0.0602999 ]
#  [0.06479971 0.04319981 0.04859979 0.05489976 0.05739975 0.05219977
#   0.04679979 0.07109969 0.07469967 0.06029973]
#  [0.06479977 0.04319984 0.04859983 0.0548998  0.05739979 0.05219981
#   0.04679983 0.07109974 0.07469973 0.06029978]]
# [[0.07199968 0.04799978 0.05399976 0.06099973 0.06377749 0.05799974
#   0.05199977 0.07899964 0.08299963 0.0669997 ]
#  [0.0719997  0.0479998  0.05399977 0.06099974 0.06377751 0.05799976
#   0.05199978 0.07899967 0.08299965 0.06699972]
#  [0.07199979 0.04799986 0.05399984 0.06099982 0.06377759 0.05799983
#   0.05199985 0.07899977 0.08299976 0.0669998 ]
#  [0.07199986 0.04799991 0.0539999  0.06099989 0.06377766 0.05799989
#   0.0519999  0.07899985 0.08299984 0.06699987]
#  [0.07199964 0.04799976 0.05399973 0.0609997  0.06377746 0.05799971
#   0.05199974 0.07899961 0.08299959 0.06699967]
#  [0.07199971 0.04799981 0.05399978 0.06099975 0.06377752 0.05799977
#   0.05199979 0.07899968 0.08299966 0.06699973]]

# %%
reg.predict(x)
# Out:
# array([72200.33048261, 44444.45217821, 53675.30448648, 57774.28894129,
#        67533.65608218, 61459.8449918 , 58781.2588805 , 78290.62826152,
#        79568.81720912, 64049.19626407])

# %%
y
# Out:
# 0    72000.000000
# 1    48000.000000
# 2    54000.000000
# 3    61000.000000
# 4    63777.777778
# 5    58000.000000
# 6    52000.000000
# 7    79000.000000
# 8    83000.000000
# 9    67000.000000
# Name: Salary, dtype: float64

# %%
theta.shape
# Out:
# (5, 1)
